# %%
import sys
import subprocess

print("Python:", sys.executable)

subprocess.run([
    sys.executable,
    "-m",
    "pip",
    "install",
    "--force-reinstall",
    "python-dotenv"
])

print("\nTesting dotenv...")
from dotenv import load_dotenv

print("SUCCESS! dotenv is working.")
# Out:
# Python: d:\GENAI-SERIES\GENAI\.venv\Scripts\python.exe
#
# Testing dotenv...
# SUCCESS! dotenv is working.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv("GROQ_API_KEY")
# Out:
# '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'

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b", streaming = True
           )
print("ChatGroq is working!")
# Out:
# ChatGroq is working!

# %%
import sys 
# !{sys.executable} -m pip install -U langchain-groq

# %%
res = llm.stream("what is data mining")
for chunk in res:
    print(chunk.content, end= "" )
# Out:
# **Data mining** is the process of automatically discovering useful patterns, relationships, and insights from large collections of data. It sits at the intersection of statistics, machine learning, databases, and domain expertise, and it turns raw data into actionable knowledge.
#
# ---
#
# ## 1. Core Idea
# - **Input:** Massive, often messy datasets (structured tables, logs, sensor streams, etc.).
# - **Goal:** Extract **non‑trivial, previously unknown** information that can support decision‑making, prediction, or description.
# - **Output:** Models, rules, clusters, visualizations, or summaries that are **interpretable** and **actionable**.
#
# ---
#
# ## 2. Typical Workflow (CRISP‑DM)
#
# | Phase | What Happens | Typical Techniques |
# |-------|--------------|---------------------|
# | **1. Business Understanding** | Define objectives, success criteria, and constraints. | – |
# ...

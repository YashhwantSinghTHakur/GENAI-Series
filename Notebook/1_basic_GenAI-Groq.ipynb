# %%
import sys
import subprocess

print("Python:", sys.executable)

subprocess.run([
    sys.executable,
    "-m",
    "pip",
    "install",
    "--force-reinstall",
    "python-dotenv"
])

print("\nTesting dotenv...")
from dotenv import load_dotenv

print("SUCCESS! dotenv is working.")
# Out:
# Python: c:\Users\Asus\anaconda3\envs\myenv\python.exe
#
# Testing dotenv...
# SUCCESS! dotenv is working.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv("GROQ_API_KEY")
# Out:
# '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'

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b",
           )
print("ChatGroq is working!")
# Out:
# ChatGroq is working!

# %%
import sys 
# !{sys.executable} -m pip install -U langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-groq) (1.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.5)
# Requirement already satisfied: sniffio in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.18)
# Requirement already satisfied: certifi in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.13.0)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.17.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (17.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.25.0)
# Requirement already satisfied: httpcore2==2.13.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Asus\anaconda3\envs\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.7.0)

# %%
res = llm.invoke("who is pm of USA")
print(res.content)
# Out:
# The United States does not have a prime minister. Its head of government (and head of state) is the President. As of my latest information (up to mid‑2024), the President was Joe Biden, whose term ends on January 20 2025. After that, the office is held by the winner of the 2024 election. If you’re looking for the current office‑holder in 2026, you’d need to check the most recent sources, since my training data doesn’t extend that far.

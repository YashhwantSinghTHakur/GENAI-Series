# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Connect with Google Gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-3.5-flash-lite")

# %%
import os 
from dotenv import load_dotenv

load_dotenv()

print("GOOGLE_API_KEY:",
      bool(os.getenv("GOOGLE_API_KEY")))
print("GEMINI_API_KEY:",
      bool(os.getenv("GEMINI_API_KEY")))
# Out:
# GOOGLE_API_KEY: True
# GEMINI_API_KEY: False

# %%
# !pip install -U langchain-google-genai google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (4.4.0)
# Requirement already satisfied: google-genai in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (2.24.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-google-genai) (1.6.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-google-genai) (2.13.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (4.15.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (16.1.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.20)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=41.0.5 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.13.0)
# Requirement already satisfied: packaging>=23.2.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.17.1)
# Requirement already satisfied: jsonpointer>=1.9 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.13.0)
# Requirement already satisfied: orjson>=3.9.14 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: httpcore2==2.13.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.8.0)
# Requirement already satisfied: cffi>=2.0.0 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pycparser in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in D:\GENAI-SERIES\GENAI\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)

# %%
try:
    response = llm.invoke("What is GenAI?")
    print(response.content)
except Exception as e:
    print(type(e).__name__)
    print(e)
# Out:
# GoogleModelNotFoundError
# Error calling model 'gemini-2.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use models/gemini-3.6-flash for the latest features and improvements. We recommend you to use the Interactions API.', 'status': 'NOT_FOUND'}}

# %%
res = llm.invoke("what is genAi?")
print(res.content)
# Out:
# [{'type': 'text', 'text': '**Generative Artificial Intelligence (GenAI)** is a type of artificial intelligence that can create new content—such as text, images, music, video, and code—in response to user prompts. \n\nUnlike traditional AI, which is designed to analyze data, recognize patterns, or make predictions (like recommending a movie on Netflix or sorting your spam email), **GenAI actually creates things that didn’t exist before.**\n\nHere is a breakdown to help you understand it better:\n\n### 1. How Does It Work?\nGenAI is powered by massive computer models (often called **Foundational Models** or **Large Language Models**). \n* **Training:** These models are trained on billions of examples of human work scraped from the internet (books, articles, artwork, photos, music).\n* **Pattern Recognition:** Instead of "memorizing" facts, the AI learns the *patterns* and *relationships* between words, pixels, or notes.\n* **Generation:** When you give it a prompt (e.g., *"Write a poem about a robot in space"*), it predicts and generates the most likely next word, pixel, or sound, one piece at a time.\n\n### 2. Common Types of GenAI (and Examples)\nDepending on what you want to create, there are different tools for the job:\n* **Text Generation:** Writes essays, emails, code, or poetry. *(Examples: OpenAI\'s ChatGPT, Google Gemini, Anthropic\'s Claude)*\n* **Image Generation:** Creates realistic photos, paintings, or logos from a text description. *(Examples: Midjourney, DALL-E, Stable Diffusion)*\n* **Video Generation:** Turns text prompts into moving video clips. *(Examples: OpenAI\'s Sora, Runway)*\n* **Audio & Music Generation:** Creates realistic voices, sound effects, or original songs. *(Examples: Suno, ElevenLabs)*\n\n### 3. Why is it a Big Deal?\n* **Accessibility:** You don’t need to know how to code, paint, or play an instrument to create things. You just use everyday language (called "natural language").\n* **Productivity:** It automates boring, repetitive tasks like summarizing long documents, drafting emails, or debugging code.\n* **Creativity:** It acts as a brainstorming partner, helping artists, writers, and businesses come up with new ideas quickly.\n\n### The Catch (Challenges)\nWhile powerful, GenAI is not perfect. It has a few major issues:\n* **Hallucinations:** GenAI models sometimes make up false information and present it as absolute fact.\n* **Copyright & Ethics:** Much of the data used to train AI was taken without permission from human creators, leading to major legal battles.\n* **Bias:** Because they are trained on human data, they can sometimes reproduce human prejudices and stereotypes. \n\n**In short:** GenAI is a digital assistant that can mimic human creativity, helping us write, draw, code, and brainstorm at the push of a button.', 'extras': {'signature': 'El4KXAFpFH0TSDXO9Fcrpj2H1NPKZYHQExkYzlBDYqwQxac3ZFcHmmYBTUKn0pLJyCDyKzJ9LZ6/oj+xj0su1eMQ/fNuasZY5VvrClD43au058eWRA4gRl2le6STnxMQ'}}]

# %% [markdown]
# Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-3.5-flash-lite")

# %%
prompts = [
    ("system", "you are a java developer."),
    ("user", "how to sort arrat.")


]
res = llm.invoke(prompts)
print(res.content)
# Out:
# [{'type': 'text', 'text': 'To sort an array in Java, you can use the built-in `java.util.Arrays` class. How you do it depends on whether your array contains **primitives** (like `int`, `double`) or **Objects** (like `String`, custom classes).\n\nHere are the most common ways:\n\n### 1. Sorting an Array of Primitives (e.g., `int[]`)\nUse `Arrays.sort()`. This uses a Dual-Pivot Quicksort, which is very efficient.\n\n```java\nimport java.util.Arrays;\n\npublic class Main {\n    public static void main(String[] args) {\n        int[] numbers = {5, 2, 8, 1, 3};\n\n        // Sort the array in ascending order\n        Arrays.sort(numbers);\n\n        // Print the sorted array\n        System.out.println(Arrays.toString(numbers)); \n        // Output: [1, 2, 3, 5, 8]\n    }\n}\n```\n\n---\n\n### 2. Sorting an Array of Objects (e.g., `String[]`)\n`Arrays.sort()` also works for Objects and Strings (using natural ordering (alphabetical for strings)).\n\n```java\nimport java.util.Arrays;\n\npublic class Main {\n    public static void main(String[] args) {\n        String[] fruits = {"Banana", "Apple", "Orange", "Mango"};\n\n        Arrays.sort(fruits);\n\n        System.out.println(Arrays.toString(fruits)); \n        // Output: [Apple, Banana, Mango, Orange]\n    }\n}\n```\n\n---\n\n### 3. Sorting in Descending Order\n* **For Objects (like `Integer[]` or `String[]`):** You can use `Collections.reverseOrder()`.\n* *Note: This does not work on primitive `int[]`, only wrapper `Integer[]`.*\n\n```java\nimport java.util.Arrays;\nimport java.util.Collections;\n\npublic class Main {\n    public static void main(String[] args) {\n        Integer[] numbers = {5, 2, 8, 1, 3};\n\n        // Sort in descending order\n        Arrays.sort(numbers, Collections.reverseOrder());\n\n        System.out.println(Arrays.toString(numbers)); \n        // Output: [8, 5, 3, 2, 1]\n    }\n}\n```\n\n*(If you need to sort a primitive `int[]` in descending order, the easiest way is to sort it normally and then reverse it, or use Java 8 Streams).*\n\n---\n\n### Summary Checklist:\n1. Always import the package: `import java.util.Arrays;`\n2. To print the array easily for debugging, use: `Arrays.toString(myArray)`', 'extras': {'signature': 'El4KXAFpFH0Tfiut/vXrFnj16B+dISyaU6T25Km8gaZeN3zTzJTdVaJogiEg/Hu0+w/ATIBp8MrS3oIvq+dpB+2qXKCNFZCuECEQhQcqxUH2YQQ46r9OhGdrjbQeCFWG'}}]

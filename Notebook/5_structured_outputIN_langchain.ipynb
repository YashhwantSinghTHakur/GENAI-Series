# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b",
           )

# %%
text = "hello my name is yashwant , age is  21 , email id is yashhwanhsy@gmail.com"

# %%
res = llm.invoke(f"give me only my name , age and email from this text: {text}")

# %%
print(res.content)
# Out:
# Name: yashwant
# Age: 21
# Email: yashhwanhsy@gmail.com

# %% [markdown]
# Solution is Srectured Output

# %%
from pydantic import BaseModel, Field
from typing import List

class ResponseStrecture(BaseModel):
    name :str = Field(description="complete Name")
    email :str = Field(description="Email Id")
    age :int = Field(description="Age")

strectured_llm = llm.with_structured_output(ResponseStrecture)

# %%
res = strectured_llm.invoke(f"give me only my name , age and email from this text: {text}")

# %%
res.model_dump()
# Out:
# {'name': 'yashwant', 'email': 'yashhwanhsy@gmail.com', 'age': 21}

# %%
res.name
# Out:
# 'yashwant'

# %%
class Movies(BaseModel):
    Name :str = Field(description="movie Name")
    Year :int = Field(description="released tear")

class AllMovies(BaseModel):
    movies:List[Movies   ]
    
movies_llm = llm.with_structured_output(Movies)
movies_llm = llm.with_structured_output(AllMovies)

# %%
movies_llm.invoke("Give me five Sci-Fi movies")
# Out:
# AllMovies(movies=[Movies(Name='Blade Runner', Year=1982), Movies(Name='The Matrix', Year=1999), Movies(Name='Inception', Year=2010), Movies(Name='Interstellar', Year=2014), Movies(Name='Arrival', Year=2016)])

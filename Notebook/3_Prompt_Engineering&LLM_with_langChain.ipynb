# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
prompts = [
    {"role":"system","content":" your a Javascript Developer?"},
    {"role":"system","content":" Difference b/w map and filter?"},

]

res = llm.invoke(prompts)
print(res.content)
# Out:
# **`Array.prototype.map()` vs. `Array.prototype.filter()`**
#
# | Aspect | `map()` | `filter()` |
# |--------|---------|------------|
# | **Purpose** | Transform each element of an array into a new value. | Select a subset of elements that satisfy a condition. |
# | **Return value** | A **new array** with the same length as the original, containing the transformed values. | A **new array** that may be shorter (or empty) containing only the elements that passed the test. |
# | **Callback signature** | `callback(currentValue, index, array) → newValue` | `callback(currentValue, index, array) → boolean` |
# | **Side‑effects** | Should be pure (no mutation of the original array), though you *can* mutate inside the callback (not recommended). | Same – should be pure, just a predicate. |
# ...

# %%
prompts = [
    {"role":"system","content":" your a translator and translate input into sanskrit"},
    {"role":"system","content":" i love you my love"},

]

res = llm.invoke(prompts)
print(res.content)
# Out:
# अहं त्वां प्रेम्णि, मम प्रिय।

# %% [markdown]
# ###Prompt Templates - Dynamic Prompts

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")
out = StrOutputParser()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system","content":" you'r a translator and translate input into {Language}"},
    {"role":"system","content":" {query}"},
    
])

# %%
chains = prompts | llm | out

# %%
res = chains.invoke({"Language": "Hinglish", "query": " hyee how are you priyam"})
print(res)
# Out:
# Hey, kaise ho Priyam?
